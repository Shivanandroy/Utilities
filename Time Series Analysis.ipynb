# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
year1 = pd.read_csv("C:\\Users\\Admin\\Downloads\\timeSeries\\y1.csv")
year2 = pd.read_csv("C:\\Users\\Admin\\Downloads\\timeSeries\\y2.csv")
year3 = pd.read_csv("C:\\Users\\Admin\\Downloads\\timeSeries\\y3.csv")
year4 = pd.read_csv("C:\\Users\\Admin\\Downloads\\timeSeries\\y4.csv")
year5 = pd.read_csv("C:\\Users\\Admin\\Downloads\\timeSeries\\y5.csv")

# %%
year1.head()
# Out:
#   Type FiscalYear  PeriodNum HQRegionDesc HQMarketSegmentDesc RegionDesc  \
# 0   HQ     Year 1          1   HQRegion 1   HQMarketSegment 1   Region 1
# 1   HQ     Year 1          1   HQRegion 1   HQMarketSegment 1   Region 1
# 2   HQ     Year 1          1   HQRegion 1   HQMarketSegment 1   Region 1
# 3   HQ     Year 1          1   HQRegion 1   HQMarketSegment 1   Region 1
# 4   HQ     Year 1          1   HQRegion 1   HQMarketSegment 1   Region 2
#
#    YTD_TER
# 0    6,942
# 1   (4,206)
# 2      -
# 3      493
# 4      -

# %%
year3.head()
# Out:
#   Type FiscalYear  PeriodNum HQRegionDesc HQMarketSegmentDesc RegionDesc  \
# 0   HQ     Year 3          1   HQRegion 1   HQMarketSegment 1   Region 1
# 1   HQ     Year 3          1   HQRegion 1   HQMarketSegment 1   Region 1
# 2   HQ     Year 3          1   HQRegion 1   HQMarketSegment 1   Region 1
# 3   HQ     Year 3          1   HQRegion 1   HQMarketSegment 1   Region 1
# 4   HQ     Year 3          1   HQRegion 1   HQMarketSegment 1   Region 1
#
#    YTD_TER
# 0   13,130
# 1      -
# 2   (3,097)
# 3      -
# 4    5,597

# %%
year2.head()
# Out:
#   Type FiscalYear  PeriodNum HQRegionDesc HQMarketSegmentDesc RegionDesc  \
# 0   HQ     Year 2          1   HQRegion 1   HQMarketSegment 1   Region 1
# 1   HQ     Year 2          1   HQRegion 1   HQMarketSegment 1   Region 1
# 2   HQ     Year 2          1   HQRegion 1   HQMarketSegment 1   Region 1
# 3   HQ     Year 2          1   HQRegion 1   HQMarketSegment 1   Region 1
# 4   HQ     Year 2          1   HQRegion 1   HQMarketSegment 1   Region 1
#
#    YTD_TER
# 0      945
# 1       11
# 2   60,291
# 3      -
# 4      -

# %%
year4.head()
# Out:
#   Type FiscalYear  PeriodNum HQRegionDesc HQMarketSegmentDesc RegionDesc  \
# 0   HQ     Year 4          1   HQRegion 1   HQMarketSegment 1   Region 1
# 1   HQ     Year 4          1   HQRegion 1   HQMarketSegment 1   Region 1
# 2   HQ     Year 4          1   HQRegion 1   HQMarketSegment 1   Region 1
# 3   HQ     Year 4          1   HQRegion 1   HQMarketSegment 1   Region 1
# 4   HQ     Year 4          1   HQRegion 1   HQMarketSegment 1   Region 1
#
#    YTD_TER
# 0   30,363
# 1      -
# 2   (3,750)
# 3      -
# 4   14,256

# %%
year5.head()
# Out:
#   Type FiscalYear  PeriodNum HQRegionDesc HQMarketSegmentDesc RegionDesc  \
# 0   HQ     Year 5          1   HQRegion 1   HQMarketSegment 1   Region 1
# 1   HQ     Year 5          1   HQRegion 1   HQMarketSegment 1   Region 1
# 2   HQ     Year 5          1   HQRegion 1   HQMarketSegment 1   Region 1
# 3   HQ     Year 5          1   HQRegion 1   HQMarketSegment 1   Region 1
# 4   HQ     Year 5          1   HQRegion 1   HQMarketSegment 1   Region 1
#
#     YTD_TER
# 0    11,996
# 1   (11,996)
# 2       108
# 3       -
# 4       -

# %%
df = pd.concat([year1, year2, year3, year4, year5])

# %%
df.shape
# Out:
# (1160720, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1160720 entries, 0 to 205709
# Data columns (total 7 columns):
# Type                   1160720 non-null object
# FiscalYear             1160720 non-null object
# PeriodNum              1160720 non-null int64
# HQRegionDesc           1160720 non-null object
# HQMarketSegmentDesc    1160720 non-null object
# RegionDesc             1160720 non-null object
#  YTD_TER               1156344 non-null object
# dtypes: int64(1), object(6)
# memory usage: 70.8+ MB

# %%
#train_df = train_df[train_df['HQRegionDesc'] == 'HQRegion 1']

# %%
df.columns
# Out:
# Index(['Type', 'FiscalYear', 'PeriodNum', 'HQRegionDesc',
#        'HQMarketSegmentDesc', 'RegionDesc', ' YTD_TER '],
#       dtype='object')

# %%
df.rename(columns={' YTD_TER ':'Revenue'}, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#   Type FiscalYear  PeriodNum HQRegionDesc HQMarketSegmentDesc RegionDesc  \
# 0   HQ     Year 1          1   HQRegion 1   HQMarketSegment 1   Region 1
# 1   HQ     Year 1          1   HQRegion 1   HQMarketSegment 1   Region 1
# 2   HQ     Year 1          1   HQRegion 1   HQMarketSegment 1   Region 1
# 3   HQ     Year 1          1   HQRegion 1   HQMarketSegment 1   Region 1
# 4   HQ     Year 1          1   HQRegion 1   HQMarketSegment 1   Region 2
#
#     Revenue
# 0    6,942
# 1   (4,206)
# 2      -
# 3      493
# 4      -

# %%
df.Revenue = df.Revenue.str.strip().replace('-', np.nan)
df.Revenue = df.Revenue.str.replace(',','')

# %%
df.Revenue
# Out:
# 0             6942
# 1           (4206)
# 2              NaN
# 3              493
# 4              NaN
# 5            34448
# 6            20680
# 7          (14379)
# 8            (160)
# 9              NaN
# 10             513
# 11            1697
# 12           17649
# 13             NaN
# 14             314
# 15             NaN
# 16             NaN
# 17             109
# 18              37
# 19             NaN
# 20            2258
# 21             NaN
# 22             531
# 23            (77)
# 24             NaN
# 25             NaN
# 26             NaN
# 27             353
# 28           16504
# 29             (1)
#             ...
# 1160690    1298211
# 1160691     702904
# 1160692      19367
# 1160693       8350
# 1160694        NaN
# 1160695     104094
# 1160696        NaN
# 1160697      80274
# 1160698     177893
# 1160699        NaN
# 1160700      37681
# 1160701     263428
# 1160702        NaN
# 1160703    (35203)
# 1160704      81465
# 1160705    (11367)
# ...

# %%
df.Revenue = df.Revenue.replace(np.nan,'-')

# %%
df.loc[df['Revenue'].str.startswith('('),'Revenue']= - df.loc[df['Revenue'].str.startswith('('),'Revenue'].str.extract('(\d+)').astype('int')
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df.Revenue
# Out:
# 0             6942
# 1            -4206
# 2                -
# 3              493
# 4                -
# 5            34448
# 6            20680
# 7           -14379
# 8             -160
# 9                -
# 10             513
# 11            1697
# 12           17649
# 13               -
# 14             314
# 15               -
# 16               -
# 17             109
# 18              37
# 19               -
# 20            2258
# 21               -
# 22             531
# 23             -77
# 24               -
# 25               -
# 26               -
# 27             353
# 28           16504
# 29              -1
#             ...
# 1160690    1298211
# 1160691     702904
# 1160692      19367
# 1160693       8350
# 1160694          -
# 1160695     104094
# 1160696          -
# 1160697      80274
# 1160698     177893
# 1160699          -
# 1160700      37681
# 1160701     263428
# 1160702          -
# 1160703     -35203
# 1160704      81465
# 1160705     -11367
# ...

# %%
pd.to_numeric(df.Revenue)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\src\inference.pyx in pandas._libs.lib.maybe_convert_numeric (pandas\_libs\lib.c:55951)()
#
# ValueError: Unable to parse string "-"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-15466ee14e9f> in <module>()
# ----> 1 pd.to_numeric(df.Revenue)
#
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     124             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     125             values = lib.maybe_convert_numeric(values, set(),
# --> 126                                                coerce_numeric=coerce_numeric)
#     127
#     128     except Exception:
#
# ...

# %%
df.Revenue.replace('Year 5','', inplace=True)

# %%
df.Revenue
# Out:
# 0             6942
# 1            -4206
# 2                -
# 3              493
# 4                -
# 5            34448
# 6            20680
# 7           -14379
# 8             -160
# 9                -
# 10             513
# 11            1697
# 12           17649
# 13               -
# 14             314
# 15               -
# 16               -
# 17             109
# 18              37
# 19               -
# 20            2258
# 21               -
# 22             531
# 23             -77
# 24               -
# 25               -
# 26               -
# 27             353
# 28           16504
# 29              -1
#             ...
# 1160690    1298211
# 1160691     702904
# 1160692      19367
# 1160693       8350
# 1160694          -
# 1160695     104094
# 1160696          -
# 1160697      80274
# 1160698     177893
# 1160699          -
# 1160700      37681
# 1160701     263428
# 1160702          -
# 1160703     -35203
# 1160704      81465
# 1160705     -11367
# ...

# %%
df.Revenue.replace('-',np.nan,inplace=True)

# %%
df.Revenue = df.Revenue.astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-f467259e32c0> in <module>()
# ----> 1 df.Revenue = df.Revenue.astype('float')
#
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3297         # else, only a single dtype is given
#    3298         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3299                                      **kwargs)
#    3300         return self._constructor(new_data).__finalize__(self)
#    3301
#
# ...

# %%
df[df.Revenue == '-3271523.37Year 5']
# Out:
#             Type FiscalYear  PeriodNum HQRegionDesc  HQMarketSegmentDesc  \
# 1159015  Inbound     Year 5          8  HQRegion 26  HQMarketSegment 217
#
#         RegionDesc            Revenue
# 1159015  Region 26  -3271523.37Year 5

# %%
df.iloc[1159015]
# Out:
# Type                               Inbound
# FiscalYear                          Year 5
# PeriodNum                                8
# HQRegionDesc                   HQRegion 26
# HQMarketSegmentDesc    HQMarketSegment 217
# RegionDesc                       Region 26
# Revenue                  -3271523.37Year 5
# Name: 1159015, dtype: object

# %%
df.Revenue = df.Revenue.str.replace('Year 5','').astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160720 entries, 0 to 1160719
# Data columns (total 7 columns):
# Type                   1160720 non-null object
# FiscalYear             1160720 non-null object
# PeriodNum              1160720 non-null int64
# HQRegionDesc           1160720 non-null object
# HQMarketSegmentDesc    1160720 non-null object
# RegionDesc             1160720 non-null object
# Revenue                504284 non-null float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 62.0+ MB

# %%
pd.options.display.float_format = '{:.2f}'.format

Monthly_df = df.groupby(['FiscalYear','PeriodNum'])['Revenue'].sum().reset_index()
Monthly_df
# Out:
#    FiscalYear  PeriodNum       Revenue
# 0      Year 1          1  190115669.00
# 1      Year 1          2  329194616.00
# 2      Year 1          3  504736394.00
# 3      Year 1          4  743094491.00
# 4      Year 1          5  946198187.00
# 5      Year 1          6 1108231172.00
# 6      Year 1          7 1368208380.00
# 7      Year 1          8 1593027619.00
# 8      Year 1          9 1807152632.00
# 9      Year 1         10 2064324620.00
# 10     Year 1         11 2248588151.00
# 11     Year 1         12 2447386971.00
# 12     Year 2          1  217569601.00
# 13     Year 2          2  382180677.00
# 14     Year 2          3  572583812.00
# 15     Year 2          4  829753646.00
# 16     Year 2          5 1038191117.00
# 17     Year 2          6 1217866773.00
# 18     Year 2          7 1470446613.00
# 19     Year 2          8 1696701491.00
# 20     Year 2          9 1937895039.00
# 21     Year 2         10 2178773037.00
# 22     Year 2         11 2375144766.00
# ...

# %%
Monthly_df_y1 = Monthly_df[Monthly_df.FiscalYear =='Year 1']
Monthly_df_y1['diff'] = Monthly_df_y1.Revenue.diff()
Monthly_df_y1.loc[0,'diff'] = Monthly_df_y1.loc[0].Revenue
Monthly_df_y1
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#    FiscalYear  PeriodNum       Revenue         diff
# 0      Year 1          1  190115669.00 190115669.00
# 1      Year 1          2  329194616.00 139078947.00
# 2      Year 1          3  504736394.00 175541778.00
# 3      Year 1          4  743094491.00 238358097.00
# ...

# %%
Monthly_df_y2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-887dd74d1d61> in <module>()
# ----> 1 Monthly_df_y2
#
# NameError: name 'Monthly_df_y2' is not defined

# %%
Monthly_df_y2 = Monthly_df[Monthly_df.FiscalYear =='Year 2']
Monthly_df_y2['diff'] = Monthly_df_y2.Revenue.diff()
Monthly_df_y2['diff'].iloc[0] = Monthly_df_y2.iloc[0].Revenue
Monthly_df_y2
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
Monthly_df_y3 = Monthly_df[Monthly_df.FiscalYear =='Year 3']
Monthly_df_y3['diff'] = Monthly_df_y3.Revenue.diff()
Monthly_df_y3['diff'].iloc[0] = Monthly_df_y3.iloc[0].Revenue
Monthly_df_y3
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
Monthly_df_y4 = Monthly_df[Monthly_df.FiscalYear =='Year 4']
Monthly_df_y4['diff'] = Monthly_df_y4.Revenue.diff()
Monthly_df_y4['diff'].iloc[0] = Monthly_df_y4.iloc[0].Revenue
Monthly_df_y4
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
Monthly_df_y5 = Monthly_df[Monthly_df.FiscalYear =='Year 5']
Monthly_df_y5['diff'] = Monthly_df_y5.Revenue.diff()
Monthly_df_y5['diff'].iloc[0] = Monthly_df_y5.iloc[0].Revenue
Monthly_df_y5
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
revenue_per_month = pd.concat([Monthly_df_y1, Monthly_df_y2, Monthly_df_y3, Monthly_df_y4, Monthly_df_y5])

# %%
revenue_per_month
# Out:
#    FiscalYear  PeriodNum       Revenue         diff
# 0      Year 1          1  190115669.00 190115669.00
# 1      Year 1          2  329194616.00 139078947.00
# 2      Year 1          3  504736394.00 175541778.00
# 3      Year 1          4  743094491.00 238358097.00
# 4      Year 1          5  946198187.00 203103696.00
# 5      Year 1          6 1108231172.00 162032985.00
# 6      Year 1          7 1368208380.00 259977208.00
# 7      Year 1          8 1593027619.00 224819239.00
# 8      Year 1          9 1807152632.00 214125013.00
# 9      Year 1         10 2064324620.00 257171988.00
# 10     Year 1         11 2248588151.00 184263531.00
# 11     Year 1         12 2447386971.00 198798820.00
# 12     Year 2          1  217569601.00 217569601.00
# 13     Year 2          2  382180677.00 164611076.00
# 14     Year 2          3  572583812.00 190403135.00
# 15     Year 2          4  829753646.00 257169834.00
# 16     Year 2          5 1038191117.00 208437471.00
# ...

# %%
rng = pd.date_range(start='Jan 2013', freq='M', periods=57)

# %%
ts = revenue_per_month.set_index(rng)
ts.rename(columns={'diff':'RevenueByMonth'}, inplace=True)
ts
# Out:
#            FiscalYear  PeriodNum       Revenue  RevenueByMonth
# 2013-01-31     Year 1          1  190115669.00    190115669.00
# 2013-02-28     Year 1          2  329194616.00    139078947.00
# 2013-03-31     Year 1          3  504736394.00    175541778.00
# 2013-04-30     Year 1          4  743094491.00    238358097.00
# 2013-05-31     Year 1          5  946198187.00    203103696.00
# 2013-06-30     Year 1          6 1108231172.00    162032985.00
# 2013-07-31     Year 1          7 1368208380.00    259977208.00
# 2013-08-31     Year 1          8 1593027619.00    224819239.00
# 2013-09-30     Year 1          9 1807152632.00    214125013.00
# 2013-10-31     Year 1         10 2064324620.00    257171988.00
# 2013-11-30     Year 1         11 2248588151.00    184263531.00
# 2013-12-31     Year 1         12 2447386971.00    198798820.00
# 2014-01-31     Year 2          1  217569601.00    217569601.00
# 2014-02-28     Year 2          2  382180677.00    164611076.00
# ...

# %%
ts.to_csv("C:\\Users\\Admin\\Downloads\\timeSeries\\ts.csv")

# %%
ts = pd.read_csv("C:\\Users\\Admin\\Downloads\\timeSeries\\ts.csv", index_col=[0], parse_dates=[0])
ts.head()
# Out:
#            FiscalYear  PeriodNum      Revenue  RevenueByMonth
# 2013-01-31     Year 1          1  190115669.0     190115669.0
# 2013-02-28     Year 1          2  329194616.0     139078947.0
# 2013-03-31     Year 1          3  504736394.0     175541778.0
# 2013-04-30     Year 1          4  743094491.0     238358097.0
# 2013-05-31     Year 1          5  946198187.0     203103696.0

# %%
# %matplotlib inline

plt.rcParams['figure.figsize'] = 14,6
plt.rcParams['axes.labelsize'] = 13
plt.rcParams['xtick.labelsize'] =13
plt.rcParams['ytick.labelsize'] =13
plt.rcParams['figure.titlesize'] =13

# %%
train = ts.loc[ts.FiscalYear != 'Year 5']
test = ts.loc[ts.FiscalYear == 'Year 5']

# %%
plt.style.use('ggplot')

plt.title('Monthly Revenue : 2013-2016')
plt.plot(train.RevenueByMonth)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=12).mean()
    rolstd = timeseries.rolling(window=12).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(train.RevenueByMonth)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
plt.subplot(411)
plt.plot(train.RevenueByMonth, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
#Test for stationarity: Original TS
rev = train.RevenueByMonth
test_stationarity(rev)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -0.12
# p-value                        0.95
# #Lags Used                    10.00
# Number of Observations Used   37.00
# Critical Value (1%)           -3.62
# Critical Value (5%)           -2.94
# Critical Value (10%)          -2.61
# dtype: float64

# %%
rev_log = np.log(rev)
rev_log_difference = rev_log - rev_log.shift()
rev_log_difference.dropna(inplace=True)

test_stationarity(rev_log_difference) #DF test clearly shows that our ts is stationary
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.11
# p-value                        0.00
# #Lags Used                    10.00
# Number of Observations Used   36.00
# Critical Value (1%)           -3.63
# Critical Value (5%)           -2.95
# Critical Value (10%)          -2.61
# dtype: float64

# %%
#plotting the ACF and PACF toobtain optimal parameters for our ARIMA Model
import statsmodels.api as sm
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(rev_log_difference, lags=10, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(rev_log_difference, lags=10, ax=ax2)
fig.tight_layout()

#p=1, q=1

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(rev_log, order=(8,1,0)).fit(disp=-1)

plt.plot(rev_log_difference, color='blue')
plt.plot(model.fittedvalues,color='red')
plt.title('RSS: %.4f' % sum((model.fittedvalues - rev_log_difference)**2))
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
print(model.summary())
# plot residual errors
residuals = pd.DataFrame(model.resid)
residuals.plot(kind='kde')
print(residuals.describe())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:       D.RevenueByMonth   No. Observations:                   47
# Model:                 ARIMA(8, 1, 0)   Log Likelihood                  33.765
# Method:                       css-mle   S.D. of innovations              0.110
# Date:                Tue, 29 Aug 2017   AIC                            -47.531
# Time:                        23:53:35   BIC                            -29.029
# Sample:                    02-28-2013   HQIC                           -40.568
#                          - 12-31-2016
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.0064      0.003      2.034      0.049       0.000       0.013
# ar.L1.D.RevenueByMonth    -0.9384      0.107     -8.745      0.000      -1.149      -0.728
# ...

# %%
predictions_ARIMA_diff = pd.Series(model.fittedvalues, copy=True)
predictions_ARIMA_diff.head()
# Out:
# 2013-02-28    0.01
# 2013-03-31    0.14
# 2013-04-30    0.07
# 2013-05-31   -0.38
# 2013-06-30   -0.16
# Freq: M, dtype: float64

# %%
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
predictions_ARIMA_log = pd.Series(rev_log.ix[0], index=rev_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(rev)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-rev)**2)/len(rev)))

# %%
predictions = np.exp(model.forecast(9)[0])
predictions
# Out:
# array([  2.72257300e+08,   2.49113027e+08,   2.05259850e+08,
#          3.06635047e+08,   2.71762115e+08,   2.20626353e+08,
#          3.02788196e+08,   2.75639816e+08,   2.69993746e+08])

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mean_absolute_percentage_error(test.RevenueByMonth,predictions)
# Out:
# 6.8647846912101809

# %%
#optimizing hyperparameters of ARIMA model

# %%
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
import warnings
 
# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(train, test, arima_order):
    
    model = ARIMA(train, order=arima_order)
    model_fit = model.fit(disp=0)
    predictions = np.exp(model_fit.forecast(9)[0])
    
	
    
    MAPE = np.mean(np.abs((test - predictions) / test)) * 100
    return MAPE
 
# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(train, test, p_values, d_values, q_values):
	train = train.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					MAPE = evaluate_arima_model(train, test, order)
					if MAPE < best_score:
						best_score, best_cfg = MAPE, order
					print('ARIMA%s MAPE=%.3f' % (order,MAPE))
				except:
					continue
	print('Best ARIMA%s MAPE=%.3f' % (best_cfg, best_score))
''' 
# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
    
'''
train = rev_log
test = test.RevenueByMonth
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")

evaluate_models(train, test, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) MAPE=17.322
# ARIMA(0, 0, 1) MAPE=17.059
# ARIMA(0, 0, 2) MAPE=17.045
# ARIMA(0, 1, 0) MAPE=12.346
# ARIMA(0, 1, 1) MAPE=12.053
# ARIMA(0, 2, 0) MAPE=96.234
# ARIMA(0, 2, 1) MAPE=12.312
# ARIMA(1, 0, 0) MAPE=17.174
# ARIMA(1, 0, 1) MAPE=17.372
# ARIMA(1, 0, 2) MAPE=17.215
# ARIMA(1, 1, 0) MAPE=11.909
# ARIMA(1, 1, 1) MAPE=12.038
# ARIMA(1, 2, 0) MAPE=12.021
# ARIMA(1, 2, 1) MAPE=13.681
# ARIMA(1, 2, 2) MAPE=13.261
# ARIMA(2, 0, 0) MAPE=17.032
# ARIMA(2, 0, 1) MAPE=14.610
# ARIMA(2, 0, 2) MAPE=17.368
# ARIMA(2, 1, 0) MAPE=12.106
# ARIMA(2, 1, 1) MAPE=12.402
# ARIMA(2, 1, 2) MAPE=12.502
# ARIMA(2, 2, 0) MAPE=12.607
# ARIMA(2, 2, 1) MAPE=12.956
# ARIMA(2, 2, 2) MAPE=12.707
# ARIMA(4, 0, 0) MAPE=14.369
# ARIMA(4, 0, 1) MAPE=14.334
# ARIMA(4, 0, 2) MAPE=14.466
# ARIMA(4, 1, 0) MAPE=12.525
# ARIMA(4, 1, 1) MAPE=11.962
# ARIMA(4, 1, 2) MAPE=11.907
# ARIMA(4, 2, 0) MAPE=17.388
# ARIMA(4, 2, 1) MAPE=19.078
# ARIMA(4, 2, 2) MAPE=12.820
# ARIMA(6, 0, 0) MAPE=15.703
# ...

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(rev_log,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue

# %%
mod = sm.tsa.statespace.SARIMAX(rev_log,
                                order=(0,0,1),
                                seasonal_order=(1, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
model_test = ARIMA(test.Revenue, order=(2,1,2)).fit(disp=-1)

plt.plot(rev_log_difference, color='blue')
plt.plot(model.fittedvalues,color='red')
plt.title('RSS: %.4f' % sum((model.fittedvalues - rev_log_difference)**2))
